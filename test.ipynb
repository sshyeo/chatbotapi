# %%
url = "https://api.themoviedb.org/3/search/movie"
params = {"query": "Inception", "api_key": "5ba70d355399491611d6e9f9ce0e5377"}
response = requests.get(url, params=params)   # <-- this is the API call
response.json()
